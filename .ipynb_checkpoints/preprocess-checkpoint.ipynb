# %%
import pandas as pd
import numpy as np
import category_encoders as ce
import logging
from sklearn.preprocessing import LabelEncoder

# Create a logger
logging.basicConfig(format="%(asctime)s %(levelname)s: %(message)s")
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ### Constants

# %%
data_dir = "data"
raw_data_dir = "raw_data"

# %% [markdown]
# ### Preprocess clinical data

# %%
df = pd.read_csv(f"{raw_data_dir}/clinical.tsv", sep="\t")
# df.columns.to_list()

# %%
# Select only some fields
selected_cols = [
    "case_submitter_id",
    "age_at_index",
    "days_to_death",
    "days_to_last_follow_up",
    "morphology",
    "ethnicity",
    "gender",
    "race",
    "vital_status",
    # "year_of_birth",
    # "year_of_death",
    "ajcc_pathologic_m",
    "ajcc_pathologic_n",
    "ajcc_pathologic_stage",
    "primary_diagnosis",
    "treatment_or_therapy",
    "treatment_type",
]

df = df[selected_cols]

# Replace '--' with NaN
df = df.replace("'--", np.nan)

logger.info(df.shape)
df
# Out:
# 2025-01-13 17:37:25,137 INFO: (1107, 15)
#      case_submitter_id age_at_index days_to_death days_to_last_follow_up  \
# 0         TCGA-62-A471           64           NaN                 1246.0
# 1         TCGA-62-A471           64           NaN                 1246.0
# 2         TCGA-67-3773           84           NaN                  427.0
# 3         TCGA-67-3773           84           NaN                  427.0
# 4         TCGA-17-Z038          NaN           NaN                    NaN
# ...                ...          ...           ...                    ...
# 1102      TCGA-55-7570           60           NaN                  824.0
# 1103      TCGA-78-7146           71           173                    NaN
# 1104      TCGA-78-7146           71           173                    NaN
# 1105      TCGA-44-3398           77           NaN                 1163.0
# 1106      TCGA-44-3398           77           NaN                 1163.0
#
#      morphology               ethnicity  gender                       race  \
# 0        8140/3  not hispanic or latino    male                      white
# 1        8140/3  not hispanic or latino    male                      white
# 2        8140/3  not hispanic or latino  female                      white
# 3        8140/3  not hispanic or latino  female                      white
# 4           NaN                     NaN     NaN                        NaN
# ...         ...                     ...     ...                        ...
# 1102     8140/3  not hispanic or latino    male  black or african american
# 1103     8255/3            not reported  female                      white
# 1104     8255/3            not reported  female                      white
# 1105     8140/3  not hispanic or latino  female                      white
# 1106     8140/3  not hispanic or latino  female                      white
#
#      vital_status ajcc_pathologic_m ajcc_pathologic_n ajcc_pathologic_stage  \
# 0           Alive                M0                N1             Stage IIB
# 1           Alive                M0                N1             Stage IIB
# 2           Alive                M0                N0              Stage IB
# 3           Alive                M0                N0              Stage IB
# 4             NaN               NaN               NaN                   NaN
# ...           ...               ...               ...                   ...
# 1102        Alive                MX                N0              Stage IA
# 1103         Dead                M0                N2            Stage IIIA
# 1104         Dead                M0                N2            Stage IIIA
# 1105        Alive                M0                N0              Stage IA
# 1106        Alive                M0                N0              Stage IA
#
#                        primary_diagnosis treatment_or_therapy  \
# 0                    Adenocarcinoma, NOS                  yes
# 1                    Adenocarcinoma, NOS                   no
# 2                    Adenocarcinoma, NOS         not reported
# 3                    Adenocarcinoma, NOS         not reported
# 4                                    NaN                  NaN
# ...                                  ...                  ...
# 1102                 Adenocarcinoma, NOS                   no
# 1103  Adenocarcinoma with mixed subtypes                   no
# 1104  Adenocarcinoma with mixed subtypes                   no
# 1105                 Adenocarcinoma, NOS                   no
# 1106                 Adenocarcinoma, NOS                   no
#
#                    treatment_type
# 0     Pharmaceutical Therapy, NOS
# 1          Radiation Therapy, NOS
# 2          Radiation Therapy, NOS
# 3     Pharmaceutical Therapy, NOS
# 4                             NaN
# ...                           ...
# 1102  Pharmaceutical Therapy, NOS
# 1103       Radiation Therapy, NOS
# 1104  Pharmaceutical Therapy, NOS
# 1105  Pharmaceutical Therapy, NOS
# 1106       Radiation Therapy, NOS
#
# [1107 rows x 15 columns]

# %%
# Add new column for Pharmaceutical Therapy, NOS
# Add new column for Radiation Therapy, NOS
df['pharmaceutical_treatment'] = ((df['treatment_type'] == 'Pharmaceutical Therapy, NOS') & (df["treatment_or_therapy"] == "yes")).astype(int)
df['radiation_treatment'] = ((df['treatment_type'] == 'Radiation Therapy, NOS') & (df["treatment_or_therapy"] == "yes")).astype(int)

# %%
# Group by 'case_submitter_id' and aggregate
df_merged = df.groupby('case_submitter_id').agg({
    "age_at_index": "first",
    "days_to_death": "first",
    "days_to_last_follow_up": "first",
    "ethnicity": "first",
    "gender": "first",
    "race": "first",
    "age_at_index": "first",
    "morphology": "first",
    "vital_status": "first",
    "ajcc_pathologic_m": "first",
    "ajcc_pathologic_n": "first",
    "ajcc_pathologic_stage": "first",
    "primary_diagnosis": "first",
    "pharmaceutical_treatment": "max",             # Update to 1 if any row has 1
    "radiation_treatment": "max"                   # Update to 1 if any row has 1
}).reset_index()

# Update 'treatment_type' based on 'treatment_or_therapy'
df_merged['treatment_type'] = np.where(df_merged['pharmaceutical_treatment'] == 1, 'Pharmaceutical Therapy, NOS', 'None')
df_merged['treatment_type'] = np.where(df_merged['radiation_treatment'] == 1, 'Radiation Therapy, NOS', df_merged['treatment_type'])

# Remove rows where 'vital_status' is NaN
df_merged = df_merged.dropna(subset=['vital_status'])

# Remove rows where 'days_to_death' or 'days_to_last_follow_up' is NaN
df_merged = df_merged[(df_merged["days_to_death"].notna()) | (df_merged["days_to_last_follow_up"].notna())]

# Convert vital_status to a binary event indicator (1 = Dead, 0 = Alive)
df_merged['event'] = (df_merged['vital_status'] == 'Dead').astype(int)

# Get 'days_to_event'
df_merged['days_to_event'] = np.where((df_merged['days_to_death'].notna()) & (df_merged['event'] == 1), df_merged['days_to_death'], df_merged['days_to_last_follow_up']).astype(float)

df_merged = df_merged[df_merged['days_to_event'] > 0]

# Drop some columns
df_merged = df_merged.drop(columns=['pharmaceutical_treatment', 'radiation_treatment'])

logger.info(f"Total samples: {df_merged.shape[0]}")
logger.info(f"Total clincal features: { df_merged.shape[1]}")

df_merged
# Out:
# 2025-01-13 17:37:25,169 INFO: Total samples: 509
# 2025-01-13 17:37:25,170 INFO: Total clincal features: 16
#     case_submitter_id age_at_index days_to_death days_to_last_follow_up  \
# 1        TCGA-05-4245           81          None                  730.0
# 2        TCGA-05-4249           67          None                 1523.0
# 3        TCGA-05-4250           79           121                   None
# 4        TCGA-05-4382           68          None                  607.0
# 5        TCGA-05-4384           66          None                  426.0
# ..                ...          ...           ...                    ...
# 580      TCGA-NJ-A55O           56          None                   13.0
# 581      TCGA-NJ-A55R           67          None                  603.0
# 582      TCGA-NJ-A7XG           49          None                  617.0
# 583      TCGA-O1-A52J           74          1798                   None
# 584      TCGA-S2-AA1A           68          None                  513.0
#
#                   ethnicity  gender                       race morphology  \
# 1              not reported    male               not reported     8140/3
# 2              not reported    male               not reported     8140/3
# 3              not reported  female               not reported     8140/3
# 4              not reported    male               not reported     8255/3
# 5              not reported    male               not reported     8255/3
# ..                      ...     ...                        ...        ...
# 580  not hispanic or latino  female                      white     8480/3
# 581  not hispanic or latino    male                      white     8230/3
# 582  not hispanic or latino    male  black or african american     8140/3
# 583  not hispanic or latino  female                      white     8140/3
# 584  not hispanic or latino  female  black or african american     8253/3
#
#     vital_status ajcc_pathologic_m ajcc_pathologic_n ajcc_pathologic_stage  \
# 1          Alive                M0                N2            Stage IIIA
# 2          Alive                M0                N0              Stage IB
# 3           Dead                M0                N1            Stage IIIA
# 4          Alive                M0                N0              Stage IB
# 5          Alive                M0                N2            Stage IIIA
# ..           ...               ...               ...                   ...
# 580        Alive                M0                N1             Stage IIA
# 581        Alive                MX                N0              Stage IA
# 582        Alive                M0                N1            Stage IIIA
# 583         Dead                MX                N0              Stage IA
# 584        Alive                M0                N0              Stage IA
#
#                          primary_diagnosis               treatment_type  \
# 1                      Adenocarcinoma, NOS                         None
# 2                      Adenocarcinoma, NOS                         None
# 3                      Adenocarcinoma, NOS                         None
# 4       Adenocarcinoma with mixed subtypes       Radiation Therapy, NOS
# 5       Adenocarcinoma with mixed subtypes       Radiation Therapy, NOS
# ..                                     ...                          ...
# 580                Mucinous adenocarcinoma                         None
# 581                   Solid carcinoma, NOS                         None
# 582                    Adenocarcinoma, NOS  Pharmaceutical Therapy, NOS
# 583                    Adenocarcinoma, NOS                         None
# 584  Bronchio-alveolar carcinoma, mucinous                         None
#
#      event  days_to_event
# 1        0          730.0
# 2        0         1523.0
# 3        1          121.0
# 4        0          607.0
# 5        0          426.0
# ..     ...            ...
# 580      0           13.0
# 581      0          603.0
# 582      0          617.0
# 583      1         1798.0
# 584      0          513.0
#
# [509 rows x 16 columns]

# %%
df_merged.to_csv(f"{data_dir}/clincal.tsv", sep="\t")

# %% [markdown]
# ### Preprocess CNV data
